# %% [markdown]
# # Catering Company - Take Home Exercise
#
# ### 1. determine the total dollar amount of coffee sales on our platform
# ### 2. suggest an approach for a coffee-pairing recommender (i.e. they've add coffee, what can/should we suggest they add?)
#
# By - Jarred Bultema

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import string
from collections import Counter
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from scipy.sparse import hstack

# %%
## import data
data_path = '../data/metro-coffee-orders.csv'
df = pd.read_csv(data_path, index_col=None)
df.head()
# Out:
#     ORDER_ID  CATERER_ID  ITEM_ID       ITEM_NAME  \
# 0  214561246      129332  5352507  Pilgrim Burger
# 1  212301212      129332  5352507  Pilgrim Burger
# 2  215326277      129332  5352507  Pilgrim Burger
# 3  214561246      129332  5352507  Pilgrim Burger
# 4  214561246      129332  5352504     Burger Bomb
#
#                                     ITEM_DESCRIPTION  ITEM_PRICE  \
# 0  With a turkey patty, stuffing, American cheese...        14.5
# 1  With a turkey patty, stuffing, American cheese...        14.5
# 2  With a turkey patty, stuffing, American cheese...        14.5
# 3  With a turkey patty, stuffing, American cheese...        14.5
# 4  With a beef patty, sauteed peppers, mushroom, ...        15.0
#
#    ITEM_QUANTITY
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %%
## quick look at dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44774 entries, 0 to 44773
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDER_ID          44774 non-null  int64
#  1   CATERER_ID        44774 non-null  int64
#  2   ITEM_ID           44774 non-null  int64
#  3   ITEM_NAME         44774 non-null  object
#  4   ITEM_DESCRIPTION  39233 non-null  object
#  5   ITEM_PRICE        44774 non-null  float64
#  6   ITEM_QUANTITY     44774 non-null  int64
# dtypes: float64(1), int64(4), object(2)
# memory usage: 2.4+ MB

# %%
## missing values in item-description...
df[df['ITEM_DESCRIPTION'].isna()].describe()
# Out:
#            ORDER_ID     CATERER_ID       ITEM_ID   ITEM_PRICE  ITEM_QUANTITY
# count  5.541000e+03    5541.000000  5.541000e+03  5541.000000    5541.000000
# mean   2.139519e+08  203976.144378  5.057343e+06    14.379709       4.267100
# std    1.363028e+06   86418.340539  1.970265e+06    23.003039       9.645211
# min    2.043744e+08    1136.000000  8.113000e+03     0.050000       1.000000
# 25%    2.130177e+08  129160.000000  3.139203e+06     2.750000       1.000000
# 50%    2.139568e+08  227856.000000  5.619153e+06     4.500000       1.000000
# 75%    2.149881e+08  266885.000000  6.749527e+06    14.500000       3.000000
# max    2.166096e+08  338933.000000  7.510281e+06   352.000000     185.000000

# %%
df[df['ITEM_DESCRIPTION'].isna()]['ITEM_NAME'].value_counts().head(25)
# Out:
# ITEM_NAME
# Bottled Water                                211
# Cheese Pizza                                 206
# Chocolate Chip Cookie                        161
# Assorted Individual Sodas                    132
# Utensils                                      97
# Box of Coffee                                 77
# Pepperoni Pizza                               67
# Fruit Platter                                 46
# Brownie                                       44
# Sweet Potato Fries                            42
# Basmati Rice                                  36
# Chips & Guacamole                             35
# Garden Salad                                  34
# Coke                                          32
# Cookie                                        32
# Chocolate Chip Cookies                        31
# Diet Coke                                     31
# Pita Bread                                    30
# Plantain Chips                                29
# Fruit Bowl                                    29
# Spicy Tuna Roll & Salmon Roll (Raw) Combo     26
# Real Fries                                    25
# Plantain Chips & Mango Salsa                  25
# Fruit Salad                                   25
# Caesar Salad                                  24
# Name: count, dtype: int64

# %% [markdown]
# ## Create the Naive target analysis (VO)

# %%
# no issue here, standard business logic
df['item_total'] = df['ITEM_PRICE'] * df['ITEM_QUANTITY']
####### START REVIEW CODE BLOCK #########
# help me review this line of code
df['is_coffee'] = df['ITEM_NAME'].str.lower().str.contains('coffee')
####### END REVIEW CODE BLOCK #########
# no issue here, but suggestions welcome
total_with_coffee = df[df['is_coffee']]['item_total'].sum().round(2)
total_without_coffee = df[~df['is_coffee']]['item_total'].sum().round(2)
coffee_percentage = round((total_with_coffee / total_without_coffee) * 100, 2)
print(f'Coffee total V0: ${total_with_coffee:,.2f}')
print(f'Non-Coffee total V0: ${total_without_coffee:,.2f}')
print(f'Coffee sales percentage V0: {coffee_percentage}%')
# Out:
# Coffee total V0: $10,068.42
# Non-Coffee total V0: $1,509,257.92
# Coffee sales percentage V0: 0.67%

# %%
## look a bit more on the naive target label
df['is_coffee'].value_counts()
# Out:
# is_coffee
# False    44523
# True       251
# Name: count, dtype: int64

# %%
## check the items detected as coffee
df[df['is_coffee']]['ITEM_NAME'].value_counts()
# Out:
# ITEM_NAME
# Box of Coffee                            113
# Fresh Brewed Stumptown Coffee             27
# Coffee                                    20
# Box of Pierce Bros. Coffee                13
# Dark Roast Coffee                         10
# Coffee Service for 10                      8
# Coffee Lover                               8
# Coffee Bowl                                7
# Box O' Joe (Hot Coffee)                    7
# Fresh Brewed Coffee                        6
# Brew for the Crew Coffee                   6
# The Dunkin' Continental w/ Hot Coffee      3
# Coffee Cake Tray                           3
# Iced Coffee                                3
# Joe to Go Coffee Box                       2
# Cold Brew Coffee                           2
# Coffee Tote                                2
# Regular Coffee                             2
# Cinnamon Coffee Cake                       1
# Freshly-Brewed Coffee                      1
# 96 Oz Box of Coffee                        1
# Deluxe Coffee & Bagel Blend                1
# Flavored Coffee Cake                       1
# Thai Iced Coffee                           1
# Iced Thai Coffee                           1
# Iced Milk Thai Coffee                      1
# Joe-To-Go Coffee Box                       1
# Name: count, dtype: int64

# %%
## check the item descriptions for these coffee items
df[df['is_coffee']][['ITEM_NAME', 'ITEM_DESCRIPTION']].drop_duplicates()
# Out:
#                                    ITEM_NAME  \
# 802                 Brew for the Crew Coffee
# 1561                           Box of Coffee
# 1827                             Coffee Bowl
# 1896                            Coffee Lover
# 2427                        Thai Iced Coffee
# 3111                             Iced Coffee
# 4151                 Box O' Joe (Hot Coffee)
# 4157   The Dunkin' Continental w/ Hot Coffee
# 5329                           Box of Coffee
# 5358                    Joe to Go Coffee Box
# 6865                           Box of Coffee
# 8237                       Dark Roast Coffee
# 9935                                  Coffee
# 10133                   Cinnamon Coffee Cake
# 10730             Box of Pierce Bros. Coffee
# 12752                          Box of Coffee
# 14986                  Coffee Service for 10
# 16200                  Freshly-Brewed Coffee
# 19455                    96 Oz Box of Coffee
# 20368                          Box of Coffee
# 21102                       Cold Brew Coffee
# 24388                          Box of Coffee
# 25772            Deluxe Coffee & Bagel Blend
# 26105                                 Coffee
# 26266                   Flavored Coffee Cake
# 29436                            Iced Coffee
# 35439                       Coffee Cake Tray
# 35785                    Fresh Brewed Coffee
# 37463                            Coffee Tote
# 38767          Fresh Brewed Stumptown Coffee
# 40466                       Iced Thai Coffee
# 40532                  Iced Milk Thai Coffee
# 40606                   Joe-To-Go Coffee Box
# 40913                       Coffee Cake Tray
# 44044                         Regular Coffee
# 44347                          Box of Coffee
#
#                                         ITEM_DESCRIPTION
# 802    96 oz fresh-brewed and hot coffee, ready to en...
# 1561                                                 NaN
# 1827   Blended coffee, almond butter, bananas, cashew...
# 1896   With almond milk, coffee, almond butter, banan...
# 2427                                                 NaN
# 3111                           With your choice of milk.
# 4151   Hot Coffee for a crowd! Dunkin’ Box O’ Joe con...
# 4157   This classic spread comes with hot coffee, ora...
# 5329                         With your choice of coffee.
# 5358   Each Joe to Go contains enough coffee for 12 e...
# 6865                                Organic & Fair Trade
# 8237   Served with sugar, sweeteners, milk, cream, an...
# 9935                                                 NaN
# 10133                                                NaN
# 10730                                                NaN
# 12752  We serve Lavazza coffee. Served with cups & lids.
# 14986                                                NaN
# 16200                        Includes 10 cups of coffee.
# 19455                                                NaN
# 20368                              Your choice of roast.
# 21102                                                NaN
# 24388                             Your choice of coffee.
# 25772  Includes 10 assorted bagels with cream cheese ...
# 26105  Your choice of roast from Speedwell Coffee Com...
# 26266  Traditional coffee cake with your choice of fl...
# 29436                                                NaN
# 35439  Assorted cinnamon crumb coffee cake, blueberry...
# 35785                                                NaN
# 37463  Our Fuel Regular medium bodied coffee is a ble...
# 38767  Your choice of coffee. Served with milk, half ...
# 40466                                                NaN
# 40532                                                NaN
# 40606                                                NaN
# 40913                    Assorted seasonal coffee cakes.
# 44044                                                NaN
# 44347                        Includes cups and stirrers.

# %% [markdown]
# #### There are least a few examples of non-coffee items detected by this naive approach.
#
# #### Are there also coffee items that are missed?

# %%
df[(df['is_coffee']==False) & (df['ITEM_DESCRIPTION'].str.contains('cof'))][['ITEM_NAME', 'ITEM_DESCRIPTION']].drop_duplicates()
# Out:
#                                                ITEM_NAME  \
# 1554                      Finagle's Egg Sandwich Platter
# 1560                               Happy Bagel Breakfast
# 1567                              Rise & Shine Breakfast
# 4770                                      The Early Bird
# 6863                               The Boardroom Package
# 7991                                   Energize Smoothie
# 8387   Juicygreens Rise and Shine Continental Breakfa...
# 9931                           The Continental Breakfast
# 9938                          Executive Breakfast Buffet
# 10582                              Breakfast Pastry Tray
# 12706                                    Super Breakfast
# 17893                         Super Hot Breakfast Buffet
# 17894                              Continental Breakfast
# 17900                                  Healthy Breakfast
# 20409                                  Premium Breakfast
# 20425                                    Basic Breakfast
# 23689                         Winner Takes All Breakfast
# 26218                            Mini Pastries & Muffins
# 26273              Employee Appreciation Month Breakfast
# 26521                             Mocha Madness Smoothie
# 28590                        Signature Breakfast Package
# 34612                                     Breakfast Nosh
# 36337                              Continental Breakfast
# 36892                                  Assorted Cupcakes
# 44058                   The Junior Continental Breakfast
# 44098                                  VIP Hot Breakfast
# 44101                          The Continental Breakfast
# 44144                            Healthy Start Breakfast
#
#                                         ITEM_DESCRIPTION
# 1554   With egg, cheese, and your choice of topping o...
# 1560   With assorted bagels, assorted whipped cream c...
# 1567   With assorted bagels, loaf cakes, scones, muff...
# 4770    Assorted breakfast pastries. Served with coffee.
# 6863   An assortment of mini breakfast pastries with ...
# 7991   With coffee, peanut butter, banana, cacao, and...
# 8387   Includes coffee, orange juice, fruit cups, car...
# 9931   Includes mini muffins, mini Danish, coffee cak...
# 9938   Includes your choice of breakfast meat, scramb...
# 10582  Includes assorted bagels, scones, coffee cakes...
# 12706  Includes turkey, ham & cheese on your choice o...
# 17893  Includes scrambled eggs, French toast, sausage...
# 17894  Includes assorted bagels, muffins, pastries, f...
# 17900  Includes yogurt, fruit salad, bagels, muffins,...
# 20409  Includes 12 mini cheese sticks (puff pastry w/...
# 20425  Includes 10 bagels, 24" chocolate babka, a var...
# 23689  Includes assorted scones, muffins, croissants ...
# 26218  Variety of morning pasties and small muffins (...
# 26273  Includes 3 pancakes per person (served w/ mapl...
# 26521  With chocolate, coffee, cappuccino, and non-fa...
# 28590  Includes scrambled eggs, roasted potatoes, bac...
# 34612  Assorted bagels, blueberry & corn muffins, cof...
# 36337  Includes assorted muffins, turnovers, Danish p...
# 36892  Assorted cupcakes (chocolate, vanilla, hostess...
# 44058  Assorted breakfast platter (fresh bagels, larg...
# 44098  Scrambled eggs, your choice of breakfast meat,...
# 44101  Assorted breakfast platter (fresh bagels, larg...
# 44144  Seasonal fruit salad, assorted Greek yogurts w...

# %%
## Naive "coffee" items
## there are few enough that I can review
df[df['is_coffee']]['ITEM_NAME'].nunique(),\
df[df['is_coffee']]['ITEM_DESCRIPTION'].nunique()
# Out:
# (27, 22)

# %%
## too many names and descriptions for manual review...
df[~df['is_coffee']]['ITEM_NAME'].nunique(),\
df[~df['is_coffee']]['ITEM_DESCRIPTION'].nunique()
# Out:
# (7266, 7354)

# %% [markdown]
# ### Refined Target-approach 1 - Use a list of keywords rather than just single term
#
# This approach employs a simple user-defined list of coffee-equivalent words to define the target. This still has potential to (1) miss coffee-sales when a different keyword is used and (2) include non-coffee items that might have these terms (theoretical ex. "chocolate covered espresso beans")
#
# Given the number of unique names and descriptions, it would be best to use a scalable NLP-approach rather than manual review. But, given the time constraints I'll quickly check for positive-associated terms.

# %%
## EDA to determine potential coffee-synonym terms
# focus on the ITEM_NAME column first
item_names = df['ITEM_NAME']

# convert to lowercase and remove punctuation
item_names = item_names.str.lower().apply(lambda x: x.translate(str.maketrans('', '', string.punctuation)))

# assuming 'is_coffee' column is accurate and exists
coffee_items = item_names[df['is_coffee']]

# tokenize the text and count word frequency
word_list = ' '.join(coffee_items).split()
word_counts = Counter(word_list)

# display the most common words in coffee item names
common_coffee_words = pd.DataFrame(word_counts.most_common(20), columns=['term', 'count'])
common_coffee_words
# Out:
#          term  count
# 0      coffee    251
# 1         box    137
# 2          of    127
# 3       fresh     33
# 4      brewed     33
# 5   stumptown     27
# 6         for     14
# 7      pierce     13
# 8        bros     13
# 9         hot     10
# 10       dark     10
# 11      roast     10
# 12        the      9
# 13        joe      9
# 14       brew      8
# 15      lover      8
# 16    service      8
# 17         10      8
# 18       bowl      7
# 19          o      7

# %%
## Repeat this approach with the item-descriptions too
item_desc = df['ITEM_DESCRIPTION'].fillna('')
item_desc = item_desc.str.lower().apply(lambda x: x.translate(str.maketrans('', '', string.punctuation)))
coffee_desc = item_desc[df['is_coffee']]

# tokenize the text and count word frequency
word_list_desc = ' '.join(coffee_desc).split()
word_counts_desc = Counter(word_list_desc)

# display the most common words
common_coffee_desc_words = pd.DataFrame(word_counts_desc.most_common(20), columns=['term', 'count'])
common_coffee_desc_words
# Out:
#           term  count
# 0       coffee    129
# 1           of     94
# 2         your     89
# 3       choice     82
# 4          and     72
# 5         with     68
# 6         milk     56
# 7         half     54
# 8       served     52
# 9        roast     45
# 10        cups     44
# 11           a     39
# 12         hot     37
# 13  sweeteners     37
# 14      almond     33
# 15          in     30
# 16        lids     28
# 17     company     28
# 18    stirrers     28
# 19      wooden     27

# %%
## let's briefly manually review these keywords to see if they seem good
coffee_keywords = ['coffee', 'espresso', 'latte', 'cappuccino', 'mocha', 'americano', 'macchiato', 'brewed', 'brew']

for term in coffee_keywords:
    tmp_desc = df[df['ITEM_DESCRIPTION'].fillna('').str.contains(term)]['ITEM_NAME'].unique().tolist()
    tmp_name = df[df['ITEM_NAME'].str.contains(term)]['ITEM_NAME'].unique().tolist()

    print(term, tmp_desc, '\n', tmp_name, '\n')
# Out:
# coffee ['Brew for the Crew Coffee', "Finagle's Egg Sandwich Platter", 'Happy Bagel Breakfast', 'Rise & Shine Breakfast', 'Coffee Bowl', 'Coffee Lover', "The Dunkin' Continental w/ Hot Coffee", 'The Early Bird', 'Box of Coffee', 'Joe to Go Coffee Box', 'The Boardroom Package', 'Energize Smoothie', 'Juicygreens Rise and Shine Continental Breakfast Menu', 'The Continental Breakfast', 'Executive Breakfast Buffet', 'Breakfast Pastry Tray', 'Super Breakfast', 'Freshly-Brewed Coffee', 'Super Hot Breakfast Buffet', 'Continental Breakfast', 'Healthy Breakfast', 'Premium Breakfast', 'Basic Breakfast', 'Winner Takes All Breakfast', 'Deluxe Coffee & Bagel Blend', 'Coffee', 'Mini Pastries & Muffins', 'Flavored Coffee Cake', 'Employee Appreciation Month Breakfast', 'Mocha Madness Smoothie', 'Signature Breakfast Package', 'Breakfast Nosh', 'Coffee Cake Tray', 'Assorted Cupcakes', 'Coffee Tote', 'Fresh Brewed Stumptown Coffee', 'The Junior Continental Breakfast', 'VIP Hot Breakfast', 'Healthy Start Breakfast']
#  []
#
# espresso ['Tiramisu', 'Chaga Espresso Smoothie', 'Frozen Mochaccino']
#  []
#
# latte ['UNO Trio Combo', 'Brown Bagging It Salad', 'Slice of Sweet Fruit Platter', 'Chocolate Dipped Indulgence Platter', 'Customize Your Own Sub Platter', 'Build-Your-Own Grain Bowl Package', 'Pasta & Chicken Combo', 'Customize Your Own Wrap Platter\xa0', 'Sandwich Buffet', 'Iced Craft Flavored Latte', 'Fruit Platter', 'Salad Platter', 'Platter Lunch Box', 'Party Platters Bundle of 3', 'The Ultimate European Breakfast Bar', 'Cheese & Cracker Platter', 'Fruit & Cheese Platter', 'Vegetarian Appetizer Plate', 'Catering for 10', 'Executive Lunch', 'Cookie Platter', 'Assorted Sandwich Platter', 'Hummus w/ Grilled Flatbread', 'Falafel Platter', 'The Junior Continental Breakfast', 'VIP Hot Breakfast', 'The Continental Breakfast']
#  ['Assorted Pita Platter', '"Mezza" Platter', 'Dominican Appetizer Platter', 'Cheese & Fruit Platter', 'Easy Order Sandwich Platter', "Finagle's Egg Sandwich Platter", 'Fruit Platter', 'Wrap Platter', 'Cookie Platter', 'Bruegger Bites Snack Platter (savory)', 'Bruegger Bites Snack Platter (sweet)', 'Appetizer Platter', 'Assorted Dessert Platter', 'Makimono Platter', 'Vegetarian Platter', 'Best of Both Platter', 'Italian Cookie Platter', 'Mini Deli Sandwich Platter', 'Sandwich & Wrap Platter', 'Feel GOOD Platter', 'Mix & Match Platter', 'Egg Wrapini Platter', 'Muffin Platter', 'Pastry Platter', 'Caesar Salad Platter', 'Sandwich Wrap Platter', 'Slice of Sweet Fruit Platter', 'Chocolate Dipped Indulgence Platter', 'Sandwich Platter', 'Roasted Eggplant Panini Platter', 'Antipasti Platter', 'Combination Dessert Platter', 'Toppings Platter', 'Customize Your Own Sub Platter', 'Assorted Cookie Platter', 'Corporate Sandwich Platter', 'Mini Pastry Platter', 'Panini Platter', 'Essential Sandwich Platter', 'Executive Sandwich Platter', 'Middle Eastern Mezze Platter', 'The Sampler Platter', 'Signature Sandwich Assorted Platter', 'Executive Lunch Platter', 'Fridays Classic App Platter', 'Traditional Wing Me Platter', 'Quesos Platter', 'Charcuteria Platter', 'Mediterraneo Platter', 'Assorted Hot Sandwich Platter', 'Assorted Cold Sandwich Platter', 'Fresh Fruit Platter', 'Fruit & Cheese Platter', 'Cheese & Crackers Platter', 'Ultimate Deli Platter', 'Dessert Platter', 'Seasonal Fruit & Cheese Platter', 'Seasonal Fruit Platter', 'Bagel & Muffin Platter', 'Assorted Muffin & Scone Platter', 'Stroller Platter', 'Salad Wrap Platter', 'Signature Sandwich Platter', 'Crostini Platter', 'Customize Your Own Wrap Platter\xa0', 'Assorted Wraps Platter', 'Grilled Chicken Caesar Wrap Platter', 'Italian Sandwich Platter', 'Caprese Panini Platter', 'Turkey Wrap Platter', 'Vegetable Wrap Platter', 'Half Wrap Platter', 'Deli Sandwich Platter', 'Deli Half Sandwich Platter', 'Signature Rolls Platter', 'Deluxe Sushi Platter', 'Veggie Sushi Platter', 'Sushi & Maki Platter', 'Cold Appetizer Platter', 'Easy Order More Sandwich Platter', 'Assorted Breakfast Platter', 'ABP Morning Pastry Platter', 'Mushroom Shawarma Sandwich Platter', 'Spicy Cauliflower "Ckn" Sandwich Platter', 'Hummus & Vegetable Platter', 'Koshari Platter', 'Roasted Tomato Garlic Eggplant Platter', 'Assorted Sandwich Platter', 'Sweets Platter', 'Breakfast Sandwich Platter', 'Fried Chicken Sandwich Platter', 'Assorted Wrap Platter', 'Turkish Dessert Platter', 'Chicken Gyro & Chicken Shish Kebab Platter', 'Skewers Platter', 'Dip Platter', 'Tropical Fruit Platter', 'Taste of Woops! Platter', 'Assorted Bagels & Pastry Platter', 'VIP Breakfast Sandwich Platter', 'Savory Platter', 'Salad Platter', 'Sweet Platter', 'Assorted Breakfast Sandwich Platter', 'Sushi & Sashimi Platter', 'Pupu Platter', 'Grilled Flank Steak Platter', 'Grilled Chicken Platter', 'Chicken Shawarma Wrap Platter', 'Falafel Wrap Platter', 'Veggie Maki Platter', 'Platter Lunch Box', 'Mixed Sandwich Platter', 'Sandwich Platter for 10', 'Sandwich Platter for 20', 'Giant Pupu Platter', 'Edamame Platter', 'Party Platters Bundle of 3', 'Fresh Harvest Vegetable Platter', 'Charcuterie & Antipasto Platter', 'BBQ Party Platter', 'Mediterranean Platter', 'Intern Sandwich Platter', 'Apprentice Sandwich Platter', 'Deluxe Assorted Sandwich Platter', 'Cookie & Brownie Platter', 'Mini French Pastry Platter', "Pavia's Premio Platter", 'Tenders Platter', "Landwer's Mediterranean Platter", 'Mixed Platter', 'Grilled Chicken Wrap Platter', 'Parmesan Chicken Sandwich Platter', 'Buffalo Chicken Wrap Platter', 'Artisanal Cheese Platter', 'Rainbow Sandwich Platter', 'Cheese & Cracker Platter', "St. Patrick's Day Vegetable Platter", 'Hummus & Veggie Platter', 'Lucky Rainbow Fruit Platter', 'Garden Salad Platter', 'Meat Panini Platter', 'Meat Wrap Platter', 'Vegetarian Wrap Platter', 'Roasted Vegetable Platter', 'Chocolate Brownie Platter', 'Deluxe Dessert Platte ...
#
# cappuccino ['Mocha Madness Smoothie']
#  []
#
# mocha ['Love Me Cupid Waffle', 'Vegan & Gluten-Free Mochaccino Cupcakes']
#  []
#
# americano []
#  []
#
# macchiato []
#  []
#
# brewed ['Brew for the Crew Coffee', 'Unsweetened Iced Tea for a Group', 'Kombucha', 'Java Box', 'Winner Takes All Breakfast', 'Ginger Kombucha', 'Blissberry Kombucha']
#  []
#
# brew ["Landwer's Famous Iced Tea", 'Brew for the Crew Coffee', 'Unsweetened Iced Tea for a Group', 'Kombucha', 'Java Box', 'Winner Takes All Breakfast', 'Ginger Kombucha', 'Blissberry Kombucha', 'Frozen Mochaccino']
#  []

# %%
## some terms seem coffee related, but are too general and would get non-coffee items
df[df['ITEM_DESCRIPTION'].fillna('').str.contains('cups')]['ITEM_NAME'].unique()
# Out:
# array(["Box O' Joe (Hot Coffee)", "The Dunkin' Continental w/ Hot Coffee",
#        'Joe to Go Coffee Box', 'Seasonal Lemonade Pitcher',
#        'Hibiscus Iced Tea Pitcher',
#        'Juicygreens Rise and Shine Continental Breakfast Menu',
#        'Box of Coffee', 'Freshly-Brewed Coffee', 'Java Box', 'Fruit Cups',
#        'Assorted Italian Pastries', 'Breakfast Pastries',
#        'Fresh Brewed Stumptown Coffee', 'Assorted Mem Tea',
#        'Strawberry Lemonade', 'Lemonade', 'Iced Tea',
#        'Broccoli Cheddar Soup'], dtype=object)

# %%
# Expanding the criteria to include more coffee-related terms
# We define a list of keywords that are likely to be in the names of coffee items
coffee_keywords = ['coffee', 'espresso', 'latte', 'cappuccino', 'mocha', 'americano', 'macchiato', 'roast', 'brewed', 'brew', 'joe']

# Creating a new column 'is_coffee_v1' with expanded criteria
df['is_coffee_v1'] = df['ITEM_NAME'].str.lower().apply(lambda x: any(keyword in x for keyword in coffee_keywords))

# Now recalculating the total dollar amount of coffee sales
total_with_coffee_v1 = df[df['is_coffee_v1']]['item_total'].sum().round(2)
total_without_coffee_v1 = df[~df['is_coffee_v1']]['item_total'].sum().round(2)
coffee_percentage_v1 = round((total_with_coffee_v1 / total_without_coffee_v1) * 100, 2)

print(f'Coffee total V1: ${total_with_coffee_v1:,.2f}')
print(f'Non-Coffee total V1: ${total_without_coffee_v1:,.2f}')
print(f'Coffee sales percentage V1: {coffee_percentage_v1}%')
# Out:
# Coffee total V1: $136,588.27
# Non-Coffee total V1: $1,382,738.07
# Coffee sales percentage V1: 9.88%

# %% [markdown]
# ### Refined Target-approach 2 - Use a list of positive-associated and negative-associated terms
#
# This approach employs a simple user-defined list of coffee-equivalent words to define the target. This still has potential to (1) miss coffee-sales when a different keyword is used and (2) include non-coffee items that might have these terms (theoretical ex. "chocolate covered espresso beans")
#
# Given the number of unique names and descriptions, it would be best to use a scalable NLP-approach rather than manual review. But, given the time constraints I'll quickly check for positive-associated terms and check for negative-associated terms. This will create inclusion-terms and exclusion-terms to use for label assignment

# %%
## can we find a simple heuristic to avoid these non-coffee items?
## let's try an exclusion list based on the bad-hits we see
exclusion_keywords = [
    'tea', 'kombucha', 'matcha', 
    'sandwich', 'bagel', 'bread', 'burger', 'sub', 'salad', 'grain', 
    'smoothie', 'tiramisu', 'cake', 'waffle', 'muffin', 
    'vegan', 
    'combo', 'platter', 'tray', 'package', 'catering', 'plate',
    'breakfast', 'lunch', 'continental', 'buffet'
    ]

# Apply lowercase to ensure consistent string matching
df['ITEM_NAME_lower'] = df['ITEM_NAME'].str.lower()
df['ITEM_DESC_lower'] = df['ITEM_DESCRIPTION'].str.lower().fillna('')

for term in coffee_keywords:
    # Filter based on coffee keywords and exclusion keywords
    tmp_desc = df[df['ITEM_DESC_lower'].str.contains(term)]['ITEM_NAME_lower'].unique()
    tmp_name = df[df['ITEM_NAME_lower'].str.contains(term)]['ITEM_NAME_lower'].unique()
    
    # Apply the exclusion criteria
    tmp_desc_clean = [name for name in tmp_desc if all(ex_keyword not in name for ex_keyword in exclusion_keywords)]
    tmp_name_clean = [name for name in tmp_name if all(ex_keyword not in name for ex_keyword in exclusion_keywords)]
    
    print(term, tmp_desc_clean, '\n', tmp_name_clean, '\n')
# Out:
# coffee ['brew for the crew coffee', 'coffee bowl', 'coffee lover', "box o' joe (hot coffee)", 'the early bird', 'box of coffee', 'joe to go coffee box', 'freshly-brewed coffee', 'java box', 'coffee', 'coffee tote', 'fresh brewed stumptown coffee']
#  ['brew for the crew coffee', 'box of coffee', 'coffee bowl', 'coffee lover', 'thai iced coffee', 'iced coffee', "box o' joe (hot coffee)", 'joe to go coffee box', 'dark roast coffee', 'coffee', 'box of pierce bros. coffee', 'coffee service for 10', 'freshly-brewed coffee', '96 oz box of coffee', 'cold brew coffee', 'fresh brewed coffee', 'coffee tote', 'fresh brewed stumptown coffee', 'iced thai coffee', 'iced milk thai coffee', 'joe-to-go coffee box', 'regular coffee']
#
# espresso ['frozen mochaccino']
#  []
#
# latte ['iced craft flavored latte']
#  ['latte', 'nitro cold brew oat milk latte', 'iced craft flavored latte', 'iced golden milk latte']
#
# cappuccino []
#  ['cappuccino']
#
# mocha ['iced craft flavored latte']
#  ['frozen mochaccino']
#
# americano []
#  []
#
# macchiato []
#  []
#
# roast ['mediterranean shakshuka', 'steel cut oatmeal', 'raita yogurt (4 oz)', 'pernil', 'costillita de puerco', 'harvest  farro', 'roasted sweet potatoes', 'greek chicken kabobs', 'marinated lamb tip kabobs', 'vegetarian kabobs', 'marinated shrimp kabobs', 'massaman curry tofu', 'roast beef & swiss panini', 'lamb & beef gyro', 'grilled vegetable gyro', 'chicken caesar gyro', 'avo & tomato toast', 'truck stop', 'teriyaki og burrito or bowl', 'vegetarian elote mexican street corn burrito', 'elote mexican street corn bowl', 'elote mexican street corn burrito or bowl', 'teriyaki og bowl', 'elote mexican street corn burrito', 'teriyaki og burrito', 'chipotle, lime & avocado bowl', 'turkey bacon avocado wrap', 'buffalo kale chicken wrap', 'masaman curry', 'vegetarian wrap', 'thin crust al pacino pizza', 'harissa bowl', 'umami bowl', 'comfort bowl', 'harvest kale bowl', 'winter cobb', 'chicken spinach wrap', 'pesto chicken panini', 'smoked turkey roll-up', 'eggplant roll-up', 'pollo marinato panini', 'chicken saltimbocca panini', 'shiitake mango bowl', 'juicy avo toast', 'pura vida warm bowl', 'arepa criolla', 'mediterranean bowl', 'zen warm bowl', 'power caesar bowl', "kane's gluten-free chocolate butter crunch", 'pistachio donut', 'roasted vegetable wrap', 'assorted cold wraps', 'shrimp burrito', 'baba ghanoush', 'sophia loren pizza', 'caprese panini', 'red coconut pumpkin curry', 'grilled vegetable display', 'garlic grilled shrimp power box', 'falafel power box', 'lemon tofu quinoa power box', 'lemon chicken quinoa power box', 'rigatoni, broccoli & chicken', 'fire-roasted tuscan vegetables', 'hongos rellenos', 'chicken shawarma wrap', 'chicken shawarma', 'roasted vegetable & kale w/ feta pie', 'roasted chicken & broccoli pizza', 'ahi tuna poke bowl', 'the orange line bowl', 'gluten-free golden chickpea curry bowl', 'golden chickpea curry bowl', 'iraklion pizza', 'cyprus pizza', 'corfu pizza', 'lamb shawarma roll-up', 'chicken shawama roll-up', 'the j.p.\xa0', 'baba dip', 'sweet potato quesadilla', 'greek pizza', 'eggplant caponata & sun-dried pesto crostini', 'the balboa pizza', 'pesto chicken pizza', 'shroomami bowl', 'chicken pesto parm bowl', 'the godfather pizza', 'baba ghanouj', 'make-your-own chicken shawarma wraps', 'coconut mousse', 'avail malabar', 'samke harra', 'bacon turkey cheddar melt', 'adobo chicken w/ avocado bowl', 'roasted turkey club', 'turkey chili', 'adobo chicken bowl', 'mediterranean lentil soup', 'thai curry tofu bowl', 'thai curry chicken bowl', 'babaghanoush & pita', 'just eggplant bowl', 'eggplant rice bowl', 'mushroom shawerma bowl', 'gluten-free just eggplant bowl', 'arrosto pizza', 'the patriot pizza', 'farmers pizza', 'the prudential pizza', 'gluten-free chicken & broccoli pizza', 'the ultimate penguin pizza', 'the blanco pizza', 'gluten-free bird pizza', 'the chicken & broccoli pizza', 'the roasted eggplant pizza', 'the fungus amongus pizza', 'gluten-free veggie pie', 'the veggie pie', 'large comfort bowl', 'shawarma chicken', 'vegetarian burrito', 'mediterranean hummus', 'arroz con pollo', 'veggie panini', 'classic dig bowl', "ani's chicken shawarma dinner", "boxed ani's chicken shawarma wrap", 'savory herb chicken', 'all american dog', 'tuscan panini', 'texas dog', 'rachel panini', 'the classic dog', 'german dog', 'bourbon st panini', 'roman panini', 'sicilian panini', 'balsamic roasted portobello panini', 'oven roasted turkey panini', 'greek vegetable chicken farro bowl', 'eggplant parmesan quinoa bowl', 'california turkey blt panini', 'veggie ciabatta', 'box of coffee', 'moroccan eggplant farro bowl', 'shrimp dopiaza', 'oven-roasted turkey panini', 'hyderabadi mirch aur baigan ka salan', 'baingan bhartha', 'baba ganoush', 'kung pao cauliflower', 'mediterranean wrap', 'vegetarian pizza', 'biryani', 'japchae', 'roasted vegetable pizza', 'vegetable & hummus wrap', 'insalata di quinoa', 'turkey club wrap', 'perugia rice bowl', 'badia wrap', 'lamb bhuna', 'coffee', 'chiles rellenos', 'teriyaki v2.0  ...
#  ['roasted mushroom & cream pasta', 'tzatziki roasted zucchini', 'oven-roasted chicken', 'roasted sweet potatoes', 'roast beef & swiss panini', 'roasted potatoes w/ lemon & herbs', 'roasted potatoes', 'oven-roasted potatoes', 'roasted garden pizza', 'roasted vegetable wrap', 'dark roast coffee', 'fire-roasted tuscan vegetables', 'lemon roasted potato wedges', 'roasted vegetable & kale w/ feta pie', 'roasted chicken & broccoli pizza', 'oven roasted eggplant parmesan pasta', 'oven roasted potatoes', '12" mushroom & roasted cauliflower pizza', 'mushroom & roasted cauliflower pizza', '12" spinach, kalamata olive & roasted garlic pizza', 'roasted broccoli caesar', 'roasted vegetables', 'roasted street corn', 'roasted turkey club', 'spinach, kalamata olive & roasted garlic pizza', 'the roasted eggplant pizza', 'balsamic roasted portobello panini', 'oven roasted turkey panini', 'oven-roasted turkey panini', 'roasted turkey breast', 'roast tomato bisque soup', 'roasted vegetable pizza', 'oven-roasted broccoli', 'maple roasted carrots', 'chicken pesto w/ roasted red peppers panini', 'roasted portobello & goat cheese pizza', 'eggplant roasted red pepper pizza', '30 simply roasted wings', 'fire-roasted caprese pizza', 'roasted salmon', 'roasted chicken', 'mixed roasted vegetables', 'roast turkey club', 'roasted broccoli', 'gluten-free mushroom & roasted cauliflower pizza', 'oven-roasted zucchini & red bell peppers', 'roasted sweet potato melt', 'roasted carrots', 'roast beef sliders', 'roasted chicken sliders', 'roast beef club', 'oven-roasted turkey wrap', 'honey roasted-garlic bbq wings', 'roasted eggplant pomodoro', 'harvest roasted crudite', 'roasted veggies wrap']
#
# brewed ['brew for the crew coffee', 'java box']
#  ['freshly-brewed coffee', 'fresh brewed coffee', 'fresh brewed stumptown coffee']
#
# brew ['brew for the crew coffee', 'java box', 'frozen mochaccino']
#  ['brew for the crew coffee', 'nitro cold brew oat milk latte', 'freshly-brewed coffee', 'cold brew coffee', 'fresh brewed coffee', 'fresh brewed stumptown coffee', 'iced honey vanilla oat cold brew']
#
# joe ["box o' joe (hot coffee)", 'joe to go coffee box']
#  ["box o' joe (hot coffee)", 'joe to go coffee box', 'buffalo joe pizza', "joe's famous fajitas", 'the smokey joe wrap', 'joe-to-go coffee box']

# %%
# Expanding the criteria to include more coffee-related terms
# We define a list of keywords that are likely to be in the names of coffee items
coffee_keywords = ['coffee', 'espresso', 'latte', 'cappuccino', 'mocha', 'americano', 'macchiato', 'roast', 'brewed', 'brew', 'joe']

# Exclusion keywords
exclusion_keywords = [
    'tea', 'kombucha', 'matcha', 
    'sandwich', 'bagel', 'bread', 'burger', 'sub', 'salad', 'grain', 
    'smoothie', 'tiramisu', 'cake', 'waffle', 'muffin', 
    'vegan', 
    'combo', 'platter', 'tray', 'package', 'catering', 'plate',
    'breakfast', 'lunch', 'continental', 'buffet'
]

# Convert both ITEM_NAME and ITEM_DESCRIPTION to lowercase for consistent matching
df['ITEM_NAME_lower'] = df['ITEM_NAME'].str.lower()
df['ITEM_DESC_lower'] = df['ITEM_DESCRIPTION'].str.lower().fillna('')  # Fill NaN with empty string

# Define 'is_coffee_v1' based on both ITEM_NAME and ITEM_DESCRIPTION
df['is_coffee_v2'] = df.apply(lambda x: (any(keyword in x['ITEM_NAME_lower'] for keyword in coffee_keywords) or 
                                         any(keyword in x['ITEM_DESC_lower'] for keyword in coffee_keywords)) and 
                                         not any(ex_keyword in x['ITEM_NAME_lower'] for ex_keyword in exclusion_keywords) and 
                                         not any(ex_keyword in x['ITEM_DESC_lower'] for ex_keyword in exclusion_keywords), axis=1)

# Recalculate the total dollar amount of coffee sales
total_with_coffee_v2 = df[df['is_coffee_v2']]['item_total'].sum().round(2)
total_without_coffee_v2 = df[~df['is_coffee_v2']]['item_total'].sum().round(2)
coffee_percentage_v2 = round((total_with_coffee_v2 / total_without_coffee_v2) * 100, 2)

print(f"Coffee total V2: ${total_with_coffee_v2:,.2f}")
print(f"Non-Coffee total V2: ${total_without_coffee_v2:,.2f}")
print(f"Coffee sales percentage V2: {coffee_percentage_v2}%")
# Out:
# Coffee total V2: $49,478.16
# Non-Coffee total V2: $1,469,848.18
# Coffee sales percentage V2: 3.37%

# %% [markdown]
# ## Refined Target-approach 3 - NLP modeling
#
# In practice, the challenge with this situation is that we lack extremely accurate target-labels for coffee vs non-coffee items (or non-exclusive coffee items like breakfast platters that have coffee included). The more robust solution is to use NLP models.
#
# I'll demonstrate one such supervised-learning approach, using the labels from V2 approach and assume they're good (mainly just for demonstration purposes).
#
# This approach will use a TFIDF transformation and then build a simple classifier to predict labels. We can also include some of the other numeric features that might be informative.

# %%
X_train_tfidf
# Out:
# <35819x3870 sparse matrix of type '<class 'numpy.float64'>'
# 	with 418402 stored elements in Compressed Sparse Row format>

# %%
# assuming 'is_coffee_v2' is an accurate target column
# preparing features
X_text = df['ITEM_NAME'] + ' ' + df['ITEM_DESCRIPTION'].fillna('')  # Combining name and description
X_numerical = df[['ITEM_PRICE', 'ITEM_QUANTITY']]  # Numerical features
# target variable
y = df['is_coffee_v2']

# Splitting the dataset
X_train_text, X_test_text, X_train_num, X_test_num, y_train, y_test = train_test_split(X_text, X_numerical, y, test_size=0.2, random_state=42)

# Text vectorization
vectorizer = TfidfVectorizer(stop_words='english')
X_train_tfidf = vectorizer.fit_transform(X_train_text)
X_test_tfidf = vectorizer.transform(X_test_text)

# Combine text and numerical features
X_train_combined = hstack([X_train_tfidf, X_train_num])
X_test_combined = hstack([X_test_tfidf, X_test_num])

# Model training
model = RandomForestClassifier(random_state=42)
model.fit(X_train_combined, y_train)

# Model evaluation
predictions = model.predict(X_test_combined)
print(classification_report(y_test, predictions))

# Generate full predictions
X_full_tfidf = vectorizer.transform(X_text)
X_full_combined = hstack([X_full_tfidf, X_numerical])
full_predictions = model.predict(X_full_combined)
df['is_coffee_v3'] = full_predictions
# Out:
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00      8525
#         True       1.00      0.94      0.97       430
#
#     accuracy                           1.00      8955
#    macro avg       1.00      0.97      0.98      8955
# weighted avg       1.00      1.00      1.00      8955

# %% [markdown]
# Precision: The ratio of correctly predicted positive observations to the total predicted positives.
# - High precision indicates that the model is effective in identifying coffee items, with fewer false positives
#
# Recall: The ratio of correctly predicted positive observations to all observations in the actual class.
# - High recall means the model is good at capturing a high proportion of actual coffee items, with fewer false negatives
#
# F1-Score: The weighted average of Precision and Recall. T
# - An excellent measure when the class distribution is imbalanced, as it maintains balance of precision and recall.
#
# Support: The number of actual occurrences of the class in the specified dataset.

# %%
# Recalculate the total dollar amount of coffee sales
total_with_coffee_v3 = df[df['is_coffee_v3']]['item_total'].sum().round(2)
total_without_coffee_v3 = df[~df['is_coffee_v3']]['item_total'].sum().round(2)
coffee_percentage_v3 = round((total_with_coffee_v3 / total_without_coffee_v3) * 100, 2)

print(f"Coffee total V3: ${total_with_coffee_v3:,.2f}")
print(f"Non-Coffee total V3: ${total_without_coffee_v3:,.2f}")
print(f"Coffee sales percentage V3: {coffee_percentage_v3}%")

# VS V2 approach which created the target labels
# I expect similar numbers
print(f"\nCoffee total V2: ${total_with_coffee_v2:,.2f}")
print(f"Non-Coffee total V2: ${total_without_coffee_v2:,.2f}")
print(f"Coffee sales percentage V2: {coffee_percentage_v2}%")
# Out:
# Coffee total V3: $48,334.99
# Non-Coffee total V3: $1,470,991.35
# Coffee sales percentage V3: 3.29%
#
# Coffee total V2: $49,478.16
# Non-Coffee total V2: $1,469,848.18
# Coffee sales percentage V2: 3.37%

# %% [markdown]
# ## Upsell Feature based on item-pairings
#
# - Determine item pairings that are often sold with coffee and perform frequency analysis
# - We'd ideally have more customer, item-category, and context info (time, date, etc) to make this analysis better

# %%
# create proxy-category feature for breakfast vs lunch to segment this analysis
# this relies on a prior assumption that coffee is more likely to be included with breakfast orders rather than lunch/dinner

# Define your category keywords
breakfast_keywords = ['egg', 'pancake', 'muffin', 'bagel', 'breakfast', 
                      'oatmeal', 'granola', 'yoghurt', 'cereal', 'waffle', 'continental', 'smoothie']
lunch_keywords = ['combo', 'sandwich', 'salad', 'burger', 'wrap', 'taco', 'pizza', 'veggie', 'vegan']

def categorize_item(item_name):
    item_name = item_name.lower()
    if any(keyword in item_name for keyword in lunch_keywords):
        # put Lunch before Breakfast so it captures those obvious lunch items first
        return 'Lunch'
    elif any(keyword in item_name for keyword in breakfast_keywords):
        return 'Breakfast'
    else:
        return 'Other'

# Apply the function to create a new category column
df['Category'] = df['ITEM_NAME'].apply(categorize_item)
df['Category'].value_counts()
# Out:
# Category
# Other        28167
# Lunch        15318
# Breakfast     1289
# Name: count, dtype: int64

# %%
# analyze coffee pairings based on these categories
coffee_orders = df[df['is_coffee_v3']]['ORDER_ID'].unique()
coffee_order_items = df[df['ORDER_ID'].isin(coffee_orders) & ~df['is_coffee_v3']]

# Group and count items by category
category_counts = coffee_order_items.groupby('Category')['ITEM_NAME'].value_counts().unstack(fill_value=0)
category_counts
## these aren't perfect, but good enough for this analysis
# Out:
# ITEM_NAME  "Chicken" Sandwich  1 Gallon Orange Juice  1-Topping Pizza Slice  \
# Category
# Breakfast                   0                      0                      0
# Lunch                      39                      0                      2
# Other                       0                      2                      0
#
# ITEM_NAME  10 Cheese Sticks  10" Gluten-Free Pizza  \
# Category
# Breakfast                 0                      0
# Lunch                     0                      1
# Other                     1                      0
#
# ITEM_NAME  10-Pack Oatmeal Raisin Chocolate Chip Cookies  \
# Category
# Breakfast                                              1
# Lunch                                                  0
# Other                                                  0
#
# ITEM_NAME  12" Buffalo Cauliflower, Scallion & Blue Cheese Pizza  \
# Category
# Breakfast                                                  0
# Lunch                                                      2
# Other                                                      0
#
# ITEM_NAME  12" Butternut Squash, Ricotta & Cranberry Pizza  12" Cheese Pizza  \
# Category
# Breakfast                                                0                 0
# Lunch                                                    4                 7
# Other                                                    0                 0
#
# ITEM_NAME  12" Chicken & Basil Pizza  ...  Yogurt, Berries & Granola  \
# Category                              ...
# Breakfast                          0  ...                          3
# Lunch                              7  ...                          0
# Other                              0  ...                          0
#
# ITEM_NAME  Yuca Fries  Yuca w/ Pickled Red Onion  Za'atar Chips  \
# Category
# Breakfast           0                          0              0
# Lunch               0                          0              0
# Other               1                          1              2
#
# ITEM_NAME  Za'atar M'anoush  Zaika Chicken Curry  Zaika Lamb Curry  \
# Category
# Breakfast                 0                    0                 0
# Lunch                     0                    0                 0
# Other                     8                    6                 2
#
# ITEM_NAME  Zen Veggie Burger  Zesty Chicken Panini Boxed Lunch  \
# Category
# Breakfast                  0                                 0
# Lunch                      9                                 0
# Other                      0                                 1
#
# ITEM_NAME  Ziti w/ Tomato-Basil Sauce
# Category
# Breakfast                           0
# Lunch                               0
# Other                               1
#
# [3 rows x 2317 columns]

# %%
# let's focus just on BREAKFAST category for this
coffee_breakfast_items = coffee_order_items[coffee_order_items['Category']=='Breakfast'].copy()

# exclude the coffee items themselves to focus on pairings
pairings = coffee_breakfast_items[~coffee_breakfast_items['is_coffee']]

# count the frequency of each item paired with coffee
pairing_counts = pairings['ITEM_NAME'].value_counts().reset_index()
pairing_counts.columns = ['Item', 'Frequency']

# display the top pairings
top_pairings = pairing_counts.head(25)
top_pairings
# Out:
#                                 Item  Frequency
# 0                     Berry Smoothie         42
# 1       Full Sized Breakfast Burrito         18
# 2                Kale Crush Smoothie         16
# 3              Tropical Sun Smoothie         15
# 4               Fresh D-Tox Smoothie         13
# 5              Mind Booster Smoothie         11
# 6              Classic Breakfast Box         10
# 7                  Power JP Smoothie          9
# 8                  Bagels & Pastries          8
# 9              Breakfast Pastry Tray          8
# 10       Assorted Muffins and Breads          8
# 11  Assorted Bagels & Pastry Platter          8
# 12               Love Child Smoothie          8
# 13               Rosa Dulce Smoothie          7
# 14                      Dozen Bagels          7
# 15                Eggplant Meatballs          6
# 16                Bagels & 3 Spreads          6
# 17                      Egg & Cheese          6
# 18               Bacon, Egg & Cheese          6
# 19                2 Hard Boiled Eggs          5
# 20                    Oatmeal Cookie          5
# 21               Nutty Love Smoothie          5
# 22         Mexican Breakfast Burrito          5
# 23                  Scallion Pancake          5
# 24         Eggplant & Chickpea Labne          5

# %% [markdown]
# This approach has given overall good results with some likely false-positive results (ex. Eggplant Meatballs), and more importantly establishes a framework that could be used to solve this problem with more accurate item- , customer-, or meal-information.
#
# In this situation, we have the same problem before we challenges with using inclusion- and exclusion-lists as the basis for labeling (category here vs target earlier). With more accurate Category/meal labels, this analysis would be improved.
